# %% [markdown]
# # 01 — Load BHSA
#
# This notebook mirrors the quickstart role in the ORACC project: load the corpus, inspect its structure, and confirm that the data can be accessed.

# %%
from google.colab import drive
drive.mount('/content/drive')

import os

PROJECT_DIR = "/content/drive/MyDrive/ALPcourse_Biblical_Hebrew_Project/biblical_hebrew_genre_analysis"
os.chdir(PROJECT_DIR + "/notebooks")

print("Current folder:")
print(os.getcwd())

# !pip -q install text-fabric pandas scikit-learn matplotlib
# Out:
# Mounted at /content/drive
# Current folder:
# /content/drive/MyDrive/ALPcourse_Biblical_Hebrew_Project/biblical_hebrew_genre_analysis/notebooks
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 52.7 MB/s eta 0:00:00

# %% [markdown]
# ## Goal
#
# Load BHSA through Text-Fabric and inspect books, chapters, verses, words, lemmas, and parts of speech.

# %%
# Install in Colab if needed:
# !pip install text-fabric pandas

from tf.app import use
import pandas as pd

# Load BHSA. This may download data on first use.
A = use('ETCBC/bhsa', hoist=globals())
# Out:
# **Locating corpus resources ...**
# The requested app is not available offline
# 	~/text-fabric-data/github/ETCBC/bhsa/app not found
# Status: latest release online v1.8.1 versus None locally
# downloading app, main data and requested additions ...
# app: ~/text-fabric-data/github/ETCBC/bhsa/app
# data: ~/text-fabric-data/github/ETCBC/bhsa/tf/2021
#    |     0.29s T otype                from ~/text-fabric-data/github/ETCBC/bhsa/tf/2021
#    |     7.57s T oslots               from ~/text-fabric-data/github/ETCBC/bhsa/tf/2021
#    |     0.01s T qere                 from ~/text-fabric-data/github/ETCBC/bhsa/tf/2021
#    |     0.00s T book@ru              from ~/text-fabric-data/github/ETCBC/bhsa/tf/2021
#    |     0.06s T book                 from ~/text-fabric-data/github/ETCBC/bhsa/tf/2021
#    |     0.01s T qere_trailer         from ~/text-fabric-data/github/ETCBC/bhsa/tf/2021
#    |     0.00s T book@de              from ~/text-fabric-data/github/ETCBC/bhsa/tf/2021
# ...

# %%
# Inspect available features
print('BHSA loaded')
print('Number of word nodes:', len(F.otype.s('word')))
# Out:
# BHSA loaded
# Number of word nodes: 426590

# %%
# Preview a few words
rows = []
for w in F.otype.s('word')[:20]:
    rows.append({
        'word_node': w,
        'text': T.text(w),
        'lex': F.lex.v(w),
        'pos': F.sp.v(w),
    })
pd.DataFrame(rows)
# Out:
#     word_node         text     lex   pos
# 0           1          בְּ       B  prep
# 1           2   רֵאשִׁ֖ית   R>CJT/  subs
# 2           3     בָּרָ֣א     BR>[  verb
# 3           4   אֱלֹהִ֑ים   >LHJM/  subs
# 4           5        אֵ֥ת       >T  prep
# 5           6           הַ       H   art
# 6           7  שָּׁמַ֖יִם    CMJM/  subs
# 7           8           וְ       W  conj
# 8           9        אֵ֥ת       >T  prep
# 9          10           הָ       H   art
# 10         11     אָֽרֶץ׃     >RY/  subs
# 11         12           וְ       W  conj
# 12         13           הָ       H   art
# 13         14      אָ֗רֶץ     >RY/  subs
# 14         15    הָיְתָ֥ה     HJH[  verb
# 15         16     תֹ֨הוּ֙     THW/  subs
# 16         17           וָ       W  conj
# 17         18      בֹ֔הוּ     BHW/  subs
# 18         19           וְ       W  conj
# 19         20    חֹ֖שֶׁךְ     XCK/  subs
